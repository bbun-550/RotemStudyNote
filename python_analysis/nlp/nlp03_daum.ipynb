# %%
# 뉴스 자료를 읽어 형태소 분석 후 단어 유사도 확인
import pandas as pd

from konlpy.tag import Okt
okt = Okt()

with open('/Users/bunny/Documents/hyundairotem_aimodel/python_analysis/nlp/daumnews.txt', 'r', encoding='utf8') as f:
  lines = f.read().splitlines()

print(lines)
# Out:
# The operation couldn’t be completed. Unable to locate a Java Runtime.
# Please visit http://www.java.com for information on installing Java.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[2], line 5
#       2 import pandas as pd
#       4 from konlpy.tag import Okt
# ----> 5 okt = Okt()
#       7 with open('/Users/bunny/Documents/hyundairotem_aimodel/python_analysis/nlp/daumnews.txt', 'r', encoding='utf8') as f:
#       8   lines = f.read().splitlines()
#
# File ~/miniconda3/envs/tf-py3.11-metal/lib/python3.11/site-packages/konlpy/tag/_okt.py:51, in Okt.__init__(self, jvmpath, max_heap_size)
#      49 def __init__(self, jvmpath=None, max_heap_size=1024):
#      50     if not jpype.isJVMStarted():
# ---> 51         jvm.init_jvm(jvmpath, max_heap_size)
#      53     oktJavaPackage = jpype.JPackage('kr.lucypark.okt')
# ...
